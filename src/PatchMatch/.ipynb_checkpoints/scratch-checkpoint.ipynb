# %%
import numpy as np
import pycuda.autoinit
import pycuda.driver as drv
import pycuda.autoinit
import pycuda.gpuarray as gpuarray
from pycuda.compiler import SourceModule
from PatchMatchCuda import PatchMatch

# %%
x = cv2.imread("../../data/raw/mona.png")
y = cv2.imread("../../data/raw/panda_a.png")
z = cv2.imread("../../data/raw/aa2.jpg")

x = cv2.resize(x,(448,448))
y = cv2.resize(y,(448,448))
z = cv2.resize(z,(448,448))


x = (x/255).transpose(1,0,2).astype(np.float32)
y = (y/255).transpose(1,0,2).astype(np.float32)
z = (z/255).astype(np.float32)

# %%
pm = PatchMatch(x,x,y,y, 5)
plt.imshow(pm.visualize())
# Out:
# called

# %%
pm.propagate(iters=5)

# %%
plt.imshow(pm.reconstruct_avg(img=y,patch_size=5)[:,:,::-1])

# %%
plt.imshow(x[:,:,::-1])

# %%
plt.imshow(pm.visualize())

# %%
x.flags
# Out:
#   C_CONTIGUOUS : False
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   UPDATEIFCOPY : False

# %%
pm.A.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   UPDATEIFCOPY : False
