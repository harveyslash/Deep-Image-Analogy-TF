# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pylab inline
import numpy as np
import pycuda.autoinit
import pycuda.driver as drv
import pycuda.autoinit
import pycuda.gpuarray as gpuarray
from pycuda.compiler import SourceModule
import cv2
from PatchMatchCuda import PatchMatch
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = cv2.imread("../../data/raw/yoda.jpeg")
y = cv2.imread("../../data/raw/ann.jpg")
z = cv2.imread("../../data/raw/aa2.jpg")

x = cv2.resize(x,(1024,1024))
y = cv2.resize(y,(1024,1024))
z = cv2.resize(z,(448,448))


x = (x/255).astype(np.float32)
y = (y/255).astype(np.float32)
z = (z/255).astype(np.float32)

# %%
pm = PatchMatch(x,x,y,y, 5)
plt.imshow(pm.visualize())
# Out:
# called

# %%
pm.propagate(iters=10,rand_search_radius=224)

# %%
plt.imshow(pm.reconstruct_image(img_a=y)[:,:,::-1])

# %%
plt.imshow(x[:,:,::-1])

# %%
plt.imshow(pm.visualize())
